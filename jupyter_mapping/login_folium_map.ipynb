# %%
# Import dependencies
import pandas as pd
import numpy as np
import folium
import folium.plugins as plugins
import os

# %%
# Find current working directory - will need later
directory = os.getcwd()
print(directory)
# Out:
# /Users/kevinricker/Desktop/IP_GEO/jupyter_mapping

# %%
# Read in dataframe we created in other jupyter notebook from excel data 
df = pd.read_pickle('df.pkl')

# %%
df.head(5)
# Out:
#      LoginName                                          UserAgent    AuditID  \
# 0    mricker33  (Windows NT 10.0; Win64; x64; rv:92.0) Gecko/2...  802661585
# 1    mricker33  (Windows NT 10.0; Win64; x64; rv:92.0) Gecko/2...  802975006
# 2    mricker33  (Windows NT 10.0; Win64; x64; rv:92.0) Gecko/2...  803035224
# 3    mricker33  (Windows NT 10.0; Win64; x64; rv:92.0) Gecko/2...  803343060
# 4  mricker2020  (Windows NT 10.0; Win64; x64; rv:92.0) Gecko/2...  803343339
#
#               DateTime  TransferOut  TransferOutAmt  \
# 0  2021-09-22 08:27:00         True         2768.93
# 1  2021-09-23 06:33:00         True         3429.87
# 2  2021-09-23 09:31:00         True         2298.36
# 3  2021-09-24 07:34:00         True         3997.60
# 4  2021-09-24 07:35:00         True         3389.75
#
#               BankInformation                 SessionId  \
# 0   322271627-JP Morgan Chase  e0g4iq51dnwyoc1leojaapzt
# 1   322271627-JP Morgan Chase  akm2tsheosyypwbju5xwlxff
# 2  062203751-Wells Fargo Bank  r4cyg0fxiyfkhvqo0omaobuh
# 3   322271627-JP Morgan Chase  sqyzf4mvi4gbr0kt01rijmd0
# 4  062203751-Wells Fargo Bank  zg0qxljlxozr5nlt21k3xw42
#
#                             Workstation   ClientAddress  Proxy  \
# 0  62423b23-40d7-44b7-9dba-d69bd40a40d1  47.208.169.208  False
# 1  1938a889-99c7-4ad1-8290-09aa8be0dba5  47.208.169.208  False
# 2  c7b1a786-ea81-4b2c-b96d-18b54f607bbc     24.32.25.90  False
# 3  5a74f3c6-7363-4fb3-91e6-39956e34a8ea     24.32.25.90  False
# 4  f259de54-ec9a-4467-ba9f-80d8e961551f  47.208.169.208  False
#
#                          ISP  Latitude  Longitude     City      Region  \
# 0  Suddenlink Communications   39.3385  -120.1729  Truckee  California
# 1  Suddenlink Communications   39.3385  -120.1729  Truckee  California
# 2  Suddenlink Communications   39.5249  -119.9031     Reno      Nevada
# 3  Suddenlink Communications   39.5249  -119.9031     Reno  California
# 4  Suddenlink Communications   39.3385  -120.1729  Truckee  California
#
#    Zipcode
# 0    96161
# 1    96161
# 2    89523
# 3    89523
# 4    96161

# %%
df.ClientAddress.unique()
# Out:
# array(['47.208.169.208', '24.32.25.90', '68.43.202.68', '24.32.222.32',
#        '24.23.128.20'], dtype=object)

# %%
data = df

# %%
token="pk.eyJ1Ijoia2NoYXJsZXNyIiwiYSI6ImNsNWVuaHBzNDEyeTIzanBlb3o4MzI3ZDAifQ.u4bzSWQGVfvAHBgGnFBVyQ"
tileurl = 'https://api.mapbox.com/v4/mapbox.satellite/{z}/{x}/{y}@2x.png?access_token=' + str(token)
m = folium.Map(location = [39.8283, -98.5795], zoom_start=4, tiles=tileurl, attr='Mapbox')
marker_cluster = folium.plugins.MarkerCluster().add_to(m)
for i in range(0,len(data)):
    html = f"""
        <h4>Login Info</h4>
        <ul>
            <li><b>Date Time :</b> {data.iloc[i]['DateTime']}</li>
            <li><b>IP :</b> {data.iloc[i]['ClientAddress']}</li>
            <li><b>Audit ID :</b> {data.iloc[i]['AuditID']}</li>
            <li><b>Provider :</b> {data.iloc[i]['ISP']}</li>
            <li><b>City :</b> {data.iloc[i]['City']}</li>
            <li><b>Amount :</b> ${data.iloc[i]['TransferOutAmt']:,.2f}</li>
            <li><b>Bank :</b> {data.iloc[i]['BankInformation']}</li>    
        </ul>
        """
    iframe = folium.IFrame(html=html, width=350, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker (
        location = [data.iloc[i]['Latitude'], data.iloc[i]['Longitude']],
        popup = popup, icon=folium.Icon(color='orange', icon='truck', prefix='fa'),
    ).add_to(marker_cluster)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cb866e020767aa5fc6461b393ab911f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cb866e020767aa5fc6461b393ab911f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2cb866e020767aa5fc6461b393ab911f = L.map(
#                 &quot;map_2cb866e020767aa5fc6461b393ab911f&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f1f6dfa1e7eb20a8298e5b6b30f7cbe = L.tileLayer(
#                 &quot;https://api.mapbox.com/v4/mapbox.satellite/{z}/{x}/{y}@2x.png?access_token=pk.eyJ1Ijoia2NoYXJsZXNyIiwiYSI6ImNsNWVuaHBzNDEyeTIzanBlb3o4MzI3ZDAifQ.u4bzSWQGVfvAHBgGnFBVyQ&quot;,
#                 {&quot;attribution&quot;: &quot;Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2cb866e020767aa5fc6461b393ab911f);
#
#
#             var marker_cluster_42b1773e1ac00d2df8040768b550dbfb = L.markerClusterGroup(
#                 {}
#             );
#             map_2cb866e020767aa5fc6461b393ab911f.addLayer(marker_cluster_42b1773e1ac00d2df8040768b550dbfb);
#
#
#             var marker_7a13d8a485f6d9998793f23b7e7d9213 = L.marker(
#                 [39.3385, -120.1729],
#                 {}
#             ).addTo(marker_cluster_42b1773e1ac00d2df8040768b550dbfb);
#
#
#             var icon_dd78553cbda94cbc6d2a43ef80bb4d74 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;truck&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7a13d8a485f6d9998793f23b7e7d9213.setIcon(icon_dd78553cbda94cbc6d2a43ef80bb4d74);
#
#
#         var popup_466636666646099b7829cc7065ed5a70 = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#             var i_frame_689cfba348b7cd629eced66d52a8d38f = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;350&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_466636666646099b7829cc7065ed5a70.setContent(i_frame_689cfba348b7cd629eced66d52a8d38f);
#
#
#         marker_7a13d8a485f6d9998793f23b7e7d9213.bindPopup(popup_466636666646099b7829cc7065ed5a70)
#         ;
#
#
#
#
#             var marker_fd55917d53fe0f4851cf4ac66720f843 = L.marker(
#                 [39.3385, -120.1729],
#                 {}
#             ).addTo(marker_cluster_42b1773e1ac00d2df8040768b550dbfb);
#
#
#             var icon_1678e93d3c9cc9594a5ea5bc24fa49b1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;truck&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fd55917d53fe0f4851cf4ac66720f843.setIcon(icon_1678e93d3c9cc9594a5ea5bc24fa49b1);
#
#
#         var popup_fc63c11eed8375bfd0cde73a13992413 = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#             var i_frame_28f7be6ab9e3b97776e7336c4860ba7c = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;350&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_fc63c11eed8375bfd0cde73a13992413.setContent(i_frame_28f7be6ab9e3b97776e7336c4860ba7c);
#
#
#         marker_fd55917d53fe0f4851cf4ac66720f843.bindPopup(popup_fc63c11eed8375bfd0cde73a13992413)
#         ;
#
#
#
#
#             var marker_69da9c4bfdaf6020272f502cd11b9024 = L.marker(
#                 [39.5249, -119.9031],
#                 {}
#             ).addTo(marker_cluster_42b1773e1ac00d2df8040768b550dbfb);
#
#
#             var icon_4fa504028ddb221dc6fec057101a44a8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;truck&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_69da9c4bfdaf6020272f502cd11b9024.setIcon(icon_4fa504028ddb221dc6fec057101a44a8);
#
#
#         var popup_d72df21feea74ef9727bf3546dfc120f = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#             var i_frame_1ec5f8ab8579c0254eec6e593cddd4c3 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;350&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_d72df21feea74ef9727bf3546dfc120f.setContent(i_frame_1ec5f8ab8579c0254eec6e593cddd4c3);
#
#
#         marker_69da9c4bfdaf6020272f502cd11b9024.bind

# %%
m.save("/Users/kevinricker/Desktop/IP_GEO/static/login_map.html")

# %%
m.save("/Users/kevinricker/Desktop/IP_GEO/index.html")
